# %%
import simpy
import pandas as pd

import random

# %%
class Printer:

    def __init__( self , env, name , speed_pps , capacity ):

        self.env = env
        self.name = name
        self.speed_pps = speed_pps

        self.tank = simpy.Container( env , init=capacity , capacity=capacity  )
        self.resource = simpy.Resource( env , capacity=1 )

        self.dfP = pd.DataFrame({
            "name" : [name]
            , "speed": [speed_pps]
            , "tank": [ capacity ]
        })

        self.dfE = pd.DataFrame()

    def print_pages( self , pages, person_name ):
        if self.tank.level > pages:
            yield self.tank.get( pages )
            print_time = pages * self.speed_pps
            yield self.env.timeout(1)
            
            print( f" { self.env.now }: { self.name } is printing { pages } pages in { print_time } secs " )
            df = pd.DataFrame({
                "time": [ self.env.now ]
                , "printer": [ self.name ]
                , "person": [ person_name ]
                , "event": [ "printing" ]
            })

            self.dfE = pd.concat( [self.dfE , df] )
            
            yield self.env.timeout( print_time )
        else:
            print( f" { self.env.now }: printer { self.name } now wo capacity!!!! :( " )
            df = pd.DataFrame({
                "time": [ self.env.now ]
                , "printer": [ self.name ]
                , "person": [ person_name ]
                , "event": [ "no resource" ]
            })

            self.dfE = pd.concat( [self.dfE , df] )

# %%
class Person:
    def __init__( self , env , name , printer , num_pages ):
        self.env = env
        self.name = name
        self.printer = printer
        self.num_pages = num_pages
        env.process( self.in_line() )

        self.dfP = pd.DataFrame({
            "name": [name]
            , "printer": [ printer.name ]
            , "num_pages": [ num_pages ]
        })

        self.dfE = pd.DataFrame()

    def in_line( self ):
        print( f" { self.env.now }: { self.name } is waiting for { self.printer.name } " )
        df = pd.DataFrame({
            "time": [ self.env.now ]
            , "printer": [ self.printer.name ]
            , "person": [ self.name ]
            , "event": [ "waiting in line" ]
        })
        self.dfE = pd.concat( [self.dfE , df] )
        with self.printer.resource.request() as request:
            yield request
            print( f" { self.env.now }: { self.name } is ready to start using { self.printer.name } " )
            yield self.env.process( self.printer.print_pages( self.num_pages , self.name ) )
            print( f" { self.env.now }: { self.name } was attended by { self.printer.name } w all pages printed " )
            df = pd.DataFrame({
                "time": [ self.env.now ]
                , "printer": [ self.printer.name ]
                , "person": [ self.name ]
                , "event": [ "finished" ]
            })
            self.dfE = pd.concat( [self.dfE , df] )
            yield self.env.timeout( 1 )

# %%
class Setup:
    def __init__( self , env , printers , num_persons ):
        self.env = env
        self.people = []
        self.num_persons = num_persons
        self.printers = [ Printer(
            env
            , f"Printer { i }"
            , random.randint( 2 , 7 )
            , random.randint( 1500 , 2200 )
        ) for i in range(printers) ]

        env.process( self.arriving() )

    def arriving(self):
        for i in range( self.num_persons ):
            self.people.append(Person(
                env
                , f"Person {i}"
                , random.choice( self.printers )
                , random.randint( 5, 25 )
            ))
            yield self.env.timeout( random.randint( 1 , 300 ) ) ## Las personas llegan aleatoriamente entre 1 - 300 segundos

# %% [markdown]
# ## Iniciamos la simulación

# %%
random.seed(111)

env = simpy.Environment()

setup = Setup( env , printers=2 , num_persons=200 )

env.run( until=30000 ) ## 8 horas
# Out:
#  0: Person 0 is waiting for Printer 1
#  0: Person 0 is ready to start using Printer 1
#  1: Printer 1 is printing 18 pages in 90 secs
#  87: Person 1 is waiting for Printer 0
#  87: Person 1 is ready to start using Printer 0
#  88: Printer 0 is printing 18 pages in 54 secs
#  91: Person 0 was attended by Printer 1 w all pages printed
#  142: Person 1 was attended by Printer 0 w all pages printed
#  374: Person 2 is waiting for Printer 0
#  374: Person 2 is ready to start using Printer 0
#  375: Printer 0 is printing 10 pages in 30 secs
#  405: Person 2 was attended by Printer 0 w all pages printed
#  612: Person 3 is waiting for Printer 1
#  612: Person 3 is ready to start using Printer 1
#  613: Printer 1 is printing 17 pages in 85 secs
#  698: Person 3 was attended by Printer 1 w all pages printed
#  755: Person 4 is waiting for Printer 1
#  755: Person 4 is ready to start using Printer 1
#  756: Printer 1 is printing 12 pages in 60 secs
#  816: Person 4 was attended by Printer 1 w all pages printed
#  935: Person 5 is waiting for Printer 1
#  935: Person 5 is ready to start using Printer 1
#  936: Printer 1 is printing 6 pages in 30 secs
#  966: Person 5 was attended by Printer 1 w all pages printed
#  1096: Person 6 is waiting for Printer 0
#  1096: Person 6 is ready to start using Printer 0
#  1097: Printer 0 is printing 23 pages in 69 secs
#  1166: Person 6 was attended by Printer 0 w all pages printed
#  1328: Person 7 is waiting for Printer 1
#  1328: Person 7 is ready to start using Printer 1
#  1329: Printer 1 is printing 7 pages in 35 secs
#  1364: Person 7 was attended by Printer 1 w all pages printed
#  1546: Person 8 is waiting for Printer 0
#  1546: Person 8 is ready to start using Printer 0
#  1547: Printer 0 is printing 14 pages in 42 secs
#  1589: Person 8 was attended by Printer 0 w all pages printed
#  1597: Person 9 is waiting for Printer 1
#  1597: Person 9 is ready to start using Printer 1
#  1598: Printer 1 is printing 19 pages in 95 secs
#  1693: Person 9 was attended by Printer 1 w all pages printed
#  1708: Person 10 is waiting for Printer 1
#  1708: Person 10 is ready to start using Printer 1
#  1709: Printer 1 is printing 12 pages in 60 secs
#  1769: Person 10 was attended by Printer 1 w all pages printed
#  1965: Person 11 is waiting for Printer 0
#  1965: Person 11 is ready to start using Printer 0
#  1966: Printer 0 is printing 5 pages in 15 secs
#  1981: Person 11 was attended by Printer 0 w all pages printed
#  2181: Person 12 is waiting for Printer 1
#  2181: Person 12 is ready to start using Printer 1
#  2182: Printer 1 is printing 20 pages in 100 secs
#  2282: Person 12 was attended by Printer 1 w all pages printed
#  2429: Person 13 is waiting for Printer 1
#  2429: Person 13 is ready to start using Printer 1
#  2430: Printer 1 is printing 22 pages in 110 secs
#  2485: Person 14 is waiting for Printer 0
#  2485: Person 14 is ready to start using Printer 0
#  2486: Printer 0 is printing 5 pages in 15 secs
#  2501: Person 14 was attended by Printer 0 w all pages printed
#  2540: Person 13 was attended by Printer 1 w all pages printed
#  2572: Person 15 is waiting for Printer 1
#  2572: Person 15 is ready to start using Printer 1
#  2573: Printer 1 is printing 25 pages in 125 secs
#  2698: Person 15 was attended by Printer 1 w all pages printed
#  2806: Person 16 is waiting for Printer 0
#  2806: Person 16 is ready to start using Printer 0
#  2807: Printer 0 is printing 16 pages in 48 secs
#  2855: Person 16 was attended by Printer 0 w all pages printed
#  2911: Person 17 is waiting for Printer 1
#  2911: Person 17 is ready to start using Printer 1
#  2912: Printer 1 is printing 9 pages in 45 secs
#  2957: Person 17 was attended by Printer 1 w all pages printed
#  2991: Person 18 is waiting for Printer 1
#  2991: Person 18 is ready to start using Printer 1
#  2992: Printer 1 is printing 23 pages in 115 secs
#  3107: Person 18 was attended by Printer 1 w all pages printed
#  3281: Person 19 is waiting for Printer 1
#  3281: Person 19 is ready to start using Printer 1
#  3282: Printer 1 is printing 5 pages in 25 secs
#  3307: Person 19 was attended by Printer 1 w all pages printed
#  3576: Person 20 is waiting for Printer 0
#  3576: Person 20 is ready to start using Printer 0
#  3577: Printer 0 is printing 9 pages in 27 secs
#  3604: Person 20 was attended by Printer 0 w all pages printed
#  3650: Person 21 is waiting for Printer 1
#  3650: Person 21 is ready to start using Printer 1
#  3651: Printer 1 is printing 16 pages in 80 secs
#  3675: Person 22 is waiting for Printer 1
#  3731: Person 21 was attended by Printer 1 w all pages printed
#  3732: Person 22 is ready to start using Printer 1
#  3733: Printer 1 is printing 6 pages in 30 secs
#  3763: Person 22 was attended by Printer 1 w all pages printed
#  3861: Person 23 is waiting for Printer 0
#  3861: Person 23 is ready to start using Printer 0
#  3862: Printer 0 is printing 23 pages in 69 secs
#  3922: Person 24 is waiting for Printer 1
#  3922: Person 24 is ready to start using Printer 1
#  3923: Printer 1 is printing 16 pages in 80 secs
#  3931: Person 23 was attended by Printer 0 w all pages printed
#  4003: Person 24 was attended by Printer 1 w all pages printed
#  4037: Person 25 is waiting for Printer 0
#  4037: Person 25 is ready to start using Printer 0
#  4038: Printer 0 is printing 23 pages in 69 secs
#  4107: Person 25 was attended by Printer 0 w all pages printed
#  4284: Person 26 is waiting for Printer 0
#  4284: Person 26 is ready to start using Printer 0
#  4285: Printer 0 is printing 21 pages in 63 secs
#  4348: Person 26 was attended by Printer 0 w all pages printed
#  4489: Person 27 is waiting for Printer 1
#  4489: Person 27 is ready to start using Printer 1
#  4490: Printer 1 is printing 11 pages in 55 secs
#  4545: Person 27 was attended by Printer 1 w all pages printed
#  4552: Person 28 is waiting for Printer 1
#  4552: Person 28 is ready to start using Printer 1
#  4553: Printer 1 is printing 13 pages in 65 secs
#  4613: Person 29 is waiting for Printer 1
#  4618: Person 28 was attended by Printer 1 w all pages printed
#  4619: Person 29 is ready to start using Printer 1
#  4620: Printer 1 is printing 9 pages in 45 secs
#  4665: Person 29 was attended by Printer 1 w all pages printed
#  4710: Person 30 is waiting for Printer 0
#  4710: Person 30 is ready to start using Printer 0
#  4711: Printer 0 is printing 20 pages in 60 secs
#  4771: Person 30 was attended by Printer 0 w all pages printed
#  4951: Person 31 is waiting for Printer 1
#  4951: Person 31 is ready to start using Printer 1
#  4952: Printer 1 is printing 6 pages in 30 secs
#  4956: Person 32 is waiting for Printer 0
#  4956: Person 32 is ready to start using Printer 0
#  4957: Printer 0 is printing 12 pages in 36 secs
#  4982: Person 31 was attended by Printer 1 w all pages printed
#  4993: Person 32 was attended by Printer 0 w all pages printed
#  5168: Person 33 is waiting for Printer 0
#  5168: Person 33 is ready to start using Printer 0
#  5169: Printer 0 is printing 6 pages in 18 secs
#  5187: Person 33 was attended by Printer 0 w all pages printed
#  5193: Person 34 is waiting for Printer 1
#  5193: Person 34 is ready to start using Printer 1
#  5194: Printer 1 is printing 13 pages in 65 secs
#  5259: Person 34 was attended by Printer 1 w all pages printed
#  5373: Person 35 is waiting for Printer 0
#  5373: Person 35 is ready to start using Printer 0
#  5374: Printer 0 is printing 25 pages in 75 secs
#  5449: Person 35 was attended by Printer 0 w all pages printed
#  5669: Person 36 is waiting for Printer 1
#  5669: Person 36 is ready to start using Printer 1
#  5670: Printer 1 is printing 15 pages in 75 secs
#  5745: Person 36 was attended by Printer 1 w all pages printed
#  5760: Person 37 is waiting for Printer 1
#  5760: Person 37 is ready to start using Printer 1
#  5761: Printer 1 is printing 16 pages in 80 secs
#  5841: Person 37 was attended by Printer 1 w all pages printed
#  5898: Person 38 is waiting for Printer 0
#  5898: Person 38 is ready to start using Printer 0
#  5899: Printer 0 is printing 17 pages in 51 secs
#  5950: Person 38 was attended by Printer 0 w all pages printed
#  6161: Person 39 is waiting for Printer 1
#  6161: Person 39 is ready to start using Printer 1
#  6162: Printer 1 is printing 23 pages in 115 secs
#  6277: Person 39 was attended by Printer 1 w all pages printed
#  6379: Person 40 is waiting for Printer 0
#  6379: Person 40 is ready to start using Printer 0
#  6380: Printer 0 is printing 17 pages in 51 secs
#  6431: Person 40 was attended by Printer 0 w all pages printed
#  6652: Person 41 is waiting for Printer 0
#  6652: Person 41 is ready to start using Printer 0
#  6653: Printer 0 is printing 23 pages in 69 secs
#  6722: Person 41 was attended by Printer 0 w all pages printed
#  6940: Person 42 is waiting for Printer 1
#  6940: Person 42 is ready to start using Printer 1
#  6941: Printer 1 is printing 8 pages in 40 secs
#  6946: Person 43 is waiting for Printer 0
#  6946: Person 43 is ready to start using Printer 0
#  6947: Printer 0 is printing 21 pages in 63 secs
#  6981: Person 42 was attended by Printer 1 w all pages printed
#  7010: Person 43 was attended by Printer 0 w all pages printed
#  7194: Person 44 is waiting for Printer 0
#  7194: Person 44 is ready to start using Printer 0
#  7195: Printer 0 is printing 23 pages in 69 secs
#  7264: Person 44 was attended by Printer 0 w all pages printed
#  7369: Person 45 is waiting for Printer 1
#  7369: Person 45 is ready to start using Printer 1
#  7370: Printer 1 is printing 22 pages in 110 secs
#  7480: Person 45 was attended by Printer 1 w all pages printed
#  7489: Person 46 is waiting for Printer 0
#  7489: Person 46 is ready to start using Printer 0
#  7490: Printer 0 is printing 15 pages in 45 secs
#  7534: Person 47 is waiting for Printer 0
#  7535: Person 46 was attended by Printer 0 w all pages printed
#  7536: Person 47 is ready to start using Printer 0
#  7537: Printer 0 is printing 14 pages in 42 secs
#  7579: Person 47 was attended by Printer 0 w all pages printed
#  7625: Person 48 is waiting for Printer 1
#  7625: Person 48 is ready to start using Printer 1
#  7626: Printer 1 is printing 24 pages in 120 secs
#  7746: Person 48 was attended by Printer 1 w all pages printed
#  7887: Person 49 is waiting for Printer 0
#  7887: Person 49 is ready to start using Printer 0
#  7888: Printer 0 is printing 23 pages in 69 secs
#  7957: Person 49 was attended by Printer 0 w all pages printed
#  8184: Person 50 is waiting for Printer 1
#  8184: Person 50 is ready to start using Printer 1
#  8185: Printer 1 is printing 6 pages in 30 secs
#  8215: Person 50 was attended by Printer 1 w all pages printed
#  8424: Person 51 is waiting for Printer 1
#  8424: Person 51 is ready to start using Printer 1
#  8425: Printer 1 is printing 18 pages in 90 secs
#  8515: Person 51 was attended by Printer 1 w all pages printed
#  8558: Person 52 is waiting for Printer 1
#  8558: Person 52 is ready to start using Printer 1
#  8559: Printer 1 is printing 14 pages in 70 secs
#  8629: Person 52 was attended by Printer 1 w all pages printed
#  8843: Person 53 is waiting for Printer 0
#  8843: Person 53 is ready to start using Printer 0
#  8844: Printer 0 is printing 5 pages in 15 secs
#  8859: Person 53 was attended by Printer 0 w all pages printed
#  8983: Person 54 is waiting for Printer 0
#  8983: Person 54 is ready to start using Printer 0
#  8984: Printer 0 is printing 11 pages in 33 secs
#  9017: Person 54 was attended by Printer 0 w all pages printed
#  9228: Person 55 is waiting for Printer 1
#  9228: Person 55 is ready to start using Printer 1
#  9229: Printer 1 is printing 24 pages in 120 secs
#  9349: Person 55 was attended by Printer 1 w all pages printed
#  9351: Person 56 is waiting for Printer 1
#  9351: Person 56 is ready to start using Printer 1
#  9352: Printer 1 is printing 19 pages in 95 secs
#  9355: Person 57 is waiting for Printer 0
#  9355: Person 57 is ready to start using Printer 0
#  9356: Printer 0 is printing 21 pages in 63 secs
#  9363: Person 58 is waiting for Printer 1
#  9419: Person 57 was attended by Printer 0 w all pages printed
#  9447: Person 56 was attended by Printer 1 w all pages printed
#  9448: Person 58 is ready to start using Printer 1
#  9449: Printer 1 is printing 19 pages in 95 secs
#  9468: Person 59 is waiting for Printer 0
#  9468: Person 59 is ready to start using Printer 0
#  9469: Printer 0 is printing 13 pages in 39 secs
#  9508: Person 59 was attended by Printer 0 w all pages printed
#  9544: Person 58 was attended by Printer 1 w all pages printed
#  9596: Person 60 is waiting for Printer 1
#  9596: Person 60 is ready to start using Printer 1
#  9597: Printer 1 is printing 21 pages in 105 secs
#  9702: Person 60 was attended by Printer 1 w all pages printed
#  9861: Person 61 is waiting for Printer 1
#  9861: Person 61 is ready to start using Printer 1
#  9862: Printer 1 is printing 17 pages in 85 secs
#  9892: Person 62 is waiting for Printer 1
#  9947: Person 61 was attended by Printer 1 w all pages printed
#  9948: Person 62 is ready to start using Printer 1
#  9949: Printer 1 is printing 19 pages in 95 secs
#  9962: Person 63 is waiting for Printer 1
#  10044: Person 62 was attended by Printer 1 w all pages printed
#  10045: Person 63 is ready to start using Printer 1
#  10046: Printer 1 is printing 19 pages in 95 secs
#  10141: Person 63 was attended by Printer 1 w all pages printed
#  10199: Person 64 is waiting for Printer 1
#  10199: Person 64 is ready to start using Printer 1
#  10200: Printer 1 is printing 18 pages in 90 secs
#  10290: Person 64 was attended by Printer 1 w all pages printed
#  10297: Person 65 is waiting for Printer 0
#  10297: Person 65 is ready to start using Printer 0
#  10298: Printer 0 is printing 20 pages in 60 secs
#  10358: Person 65 was attended by Printer 0 w all pages printed
#  10367: Person 66 is waiting for Printer 1
#  10367: Person 66 is ready to start using Printer 1
#  10368: Printer 1 is printing 13 pages in 65 secs
#  10433: Person 66 was attended by Printer 1 w all pages printed
#  10617: Person 67 is waiting for Printer 0
#  10617: Person 67 is ready to start using Printer 0
#  10618: Printer 0 is printing 14 pages in 42 secs
#  10660: Person 67 was attended by Printer 0 w all pages printed
#  10771: Person 68 is waiting for Printer 1
#  10771: Person 68 is ready to start using Printer 1
#  10772: Printer 1 is printing 23 pages in 115 secs
#  10887: Person 68 was attended by Printer 1 w all pages printed
#  10904: Person 69 is waiting for Printer 1
#  10904: Person 69 is ready to start using Printer 1
#  10905: Printer 1 is printing 25 pages in 125 secs
#  11030: Person 69 was attended by Printer 1 w all pages printed
#  11145: Person 70 is waiting for Printer 1
#  11145: Person 70 is ready to start using Printer 1
#  11146: Printer 1 is printing 23 pages in 115 secs
#  11246: Person 71 is waiting for Printer 0
#  11246: Person 71 is ready to start using Printer 0
#  11247: Printer 0 is printing 13 pages in 39 secs
#  11261: Person 70 was attended by Printer 1 w all pages printed
#  11286: Person 71 was attended by Printer 0 w all pages printed
#  11323: Person 72 is waiting for Printer 1
#  11323: Person 72 is ready to start using Printer 1
#  11324: Printer 1 is printing 11 pages in 55 secs
#  11379: Person 72 was attended by Printer 1 w all pages printed
#  11537: Person 73 is waiting for Printer 0
#  11537: Person 73 is ready to start using Printer 0
#  11538: Printer 0 is printing 25 pages in 75 secs
#  11613: Person 73 was attended by Printer 0 w all pages printed
#  11699: Person 74 is waiting for Printer 1
#  11699: Person 74 is ready to start using Printer 1
#  11700: Printer 1 is printing 21 pages in 105 secs
#  11805: Person 74 was attended by Printer 1 w all pages printed
#  11977: Person 75 is waiting for Printer 0
#  11977: Person 75 is ready to start using Printer 0
#  11978: Printer 0 is printing 18 pages in 54 secs
#  12032: Person 75 was attended by Printer 0 w all pages printed
#  12107: Person 76 is waiting for Printer 0
#  12107: Person 76 is ready to start using Printer 0
#  12108: Printer 0 is printing 5 pages in 15 secs
#  12112: Person 77 is waiting for Printer 0
#  12123: Person 76 was attended by Printer 0 w all pages printed
#  12124: Person 77 is ready to start using Printer 0
#  12125: Printer 0 is printing 8 pages in 24 secs
#  12149: Person 77 was attended by Printer 0 w all pages printed
#  12219: Person 78 is waiting for Printer 0
#  12219: Person 78 is ready to start using Printer 0
#  12220: Printer 0 is printing 12 pages in 36 secs
#  12256: Person 78 was attended by Printer 0 w all pages printed
#  12450: Person 79 is waiting for Printer 0
#  12450: Person 79 is ready to start using Printer 0
#  12451: Printer 0 is printing 19 pages in 57 secs
#  12489: Person 80 is waiting for Printer 0
#  12508: Person 79 was attended by Printer 0 w all pages printed
#  12509: Person 80 is ready to start using Printer 0
#  12510: Printer 0 is printing 20 pages in 60 secs
#  12570: Person 80 was attended by Printer 0 w all pages printed
#  12737: Person 81 is waiting for Printer 1
#  12737: Person 81 is ready to start using Printer 1
#  12738: Printer 1 is printing 19 pages in 95 secs
#  12833: Person 81 was attended by Printer 1 w all pages printed
#  12934: Person 82 is waiting for Printer 0
#  12934: Person 82 is ready to start using Printer 0
#  12935: Printer 0 is printing 21 pages in 63 secs
#  12998: Person 82 was attended by Printer 0 w all pages printed
#  13027: Person 83 is waiting for Printer 1
#  13027: Person 83 is ready to start using Printer 1
#  13028: Printer 1 is printing 12 pages in 60 secs
#  13088: Person 83 was attended by Printer 1 w all pages printed
#  13223: Person 84 is waiting for Printer 0
#  13223: Person 84 is ready to start using Printer 0
#  13224: Printer 0 is printing 21 pages in 63 secs
#  13248: Person 85 is waiting for Printer 0
#  13287: Person 84 was attended by Printer 0 w all pages printed
#  13288: Person 85 is ready to start using Printer 0
#  13289: Printer 0 is printing 7 pages in 21 secs
#  13310: Person 85 was attended by Printer 0 w all pages printed
#  13471: Person 86 is waiting for Printer 0
#  13471: Person 86 is ready to start using Printer 0
#  13472: Printer 0 is printing 21 pages in 63 secs
#  13535: Person 86 was attended by Printer 0 w all pages printed
#  13629: Person 87 is waiting for Printer 0
#  13629: Person 87 is ready to start using Printer 0
#  13630: Printer 0 is printing 12 pages in 36 secs
#  13666: Person 87 was attended by Printer 0 w all pages printed
#  13911: Person 88 is waiting for Printer 0
#  13911: Person 88 is ready to start using Printer 0
#  13912: Printer 0 is printing 7 pages in 21 secs
#  13933: Person 88 was attended by Printer 0 w all pages printed
#  13943: Person 89 is waiting for Printer 1
#  13943: Person 89 is ready to start using Printer 1
#  13944: Printer 1 is printing 25 pages in 125 secs
#  14069: Person 89 was attended by Printer 1 w all pages printed
#  14081: Person 90 is waiting for Printer 0
#  14081: Person 90 is ready to start using Printer 0
#  14082: Printer 0 is printing 5 pages in 15 secs
#  14097: Person 90 was attended by Printer 0 w all pages printed
#  14102: Person 91 is waiting for Printer 0
#  14102: Person 91 is ready to start using Printer 0
#  14103: Printer 0 is printing 20 pages in 60 secs
#  14163: Person 91 was attended by Printer 0 w all pages printed
#  14189: Person 92 is waiting for Printer 1
#  14189: Person 92 is ready to start using Printer 1
#  14190: Printer 1 is printing 21 pages in 105 secs
#  14295: Person 92 was attended by Printer 1 w all pages printed
#  14399: Person 93 is waiting for Printer 1
#  14399: Person 93 is ready to start using Printer 1
#  14400: Printer 1 is printing 17 pages in 85 secs
#  14485: Person 93 was attended by Printer 1 w all pages printed
#  14490: Person 94 is waiting for Printer 1
#  14490: Person 94 is ready to start using Printer 1
#  14491: Printer 1 is printing 14 pages in 70 secs
#  14503: Person 95 is waiting for Printer 1
#  14561: Person 94 was attended by Printer 1 w all pages printed
#  14562: Person 95 is ready to start using Printer 1
#  14563: Printer 1 is printing 24 pages in 120 secs
#  14683: Person 95 was attended by Printer 1 w all pages printed
#  14765: Person 96 is waiting for Printer 1
#  14765: Person 96 is ready to start using Printer 1
#  14766: Printer 1 is printing 10 pages in 50 secs
#  14816: Person 96 was attended by Printer 1 w all pages printed
#  14894: Person 97 is waiting for Printer 0
#  14894: Person 97 is ready to start using Printer 0
#  14895: Printer 0 is printing 23 pages in 69 secs
#  14933: Person 98 is waiting for Printer 1
#  14933: Person 98 is ready to start using Printer 1
#  14934: Printer 1 is printing 24 pages in 120 secs
#  14964: Person 97 was attended by Printer 0 w all pages printed
#  15043: Person 99 is waiting for Printer 1
#  15054: Person 98 was attended by Printer 1 w all pages printed
#  15055: Person 99 is ready to start using Printer 1
#  15056: Printer 1 is printing 5 pages in 25 secs
#  15081: Person 99 was attended by Printer 1 w all pages printed
#  15161: Person 100 is waiting for Printer 0
#  15161: Person 100 is ready to start using Printer 0
#  15162: Printer 0 is printing 17 pages in 51 secs
#  15213: Person 100 was attended by Printer 0 w all pages printed
#  15286: Person 101 is waiting for Printer 1
#  15286: Person 101 is ready to start using Printer 1
#  15287: Printer 1 is printing 13 pages in 65 secs
#  15352: Person 101 was attended by Printer 1 w all pages printed
#  15488: Person 102 is waiting for Printer 0
#  15488: Person 102 is ready to start using Printer 0
#  15489: Printer 0 is printing 14 pages in 42 secs
#  15531: Person 102 was attended by Printer 0 w all pages printed
#  15782: Person 103 is waiting for Printer 1
#  15782: Person 103 is ready to start using Printer 1
#  15783: Printer 1 is printing 23 pages in 115 secs
#  15789: Person 104 is waiting for Printer 0
#  15789: Person 104 is ready to start using Printer 0
#  15790: Printer 0 is printing 18 pages in 54 secs
#  15844: Person 104 was attended by Printer 0 w all pages printed
#  15898: Person 103 was attended by Printer 1 w all pages printed
#  16038: Person 105 is waiting for Printer 0
#  16038: Person 105 is ready to start using Printer 0
#  16039: Printer 0 is printing 10 pages in 30 secs
#  16069: Person 105 was attended by Printer 0 w all pages printed
#  16232: Person 106 is waiting for Printer 0
#  16232: Person 106 is ready to start using Printer 0
#  16233: Printer 0 is printing 8 pages in 24 secs
#  16257: Person 106 was attended by Printer 0 w all pages printed
#  16269: Person 107 is waiting for Printer 0
#  16269: Person 107 is ready to start using Printer 0
#  16270: Printer 0 is printing 13 pages in 39 secs
#  16309: Person 107 was attended by Printer 0 w all pages printed
#  16351: Person 108 is waiting for Printer 0
#  16351: Person 108 is ready to start using Printer 0
#  16352: Printer 0 is printing 25 pages in 75 secs
#  16427: Person 108 was attended by Printer 0 w all pages printed
#  16649: Person 109 is waiting for Printer 0
#  16649: Person 109 is ready to start using Printer 0
#  16650: Printer 0 is printing 11 pages in 33 secs
#  16683: Person 109 was attended by Printer 0 w all pages printed
#  16841: Person 110 is waiting for Printer 0
#  16841: Person 110 is ready to start using Printer 0
#  16842: Printer 0 is printing 15 pages in 45 secs
#  16887: Person 110 was attended by Printer 0 w all pages printed
#  17092: Person 111 is waiting for Printer 1
#  17092: Person 111 is ready to start using Printer 1
#  17093: Printer 1 is printing 8 pages in 40 secs
#  17114: Person 112 is waiting for Printer 0
#  17114: Person 112 is ready to start using Printer 0
#  17115: Printer 0 is printing 10 pages in 30 secs
#  17133: Person 111 was attended by Printer 1 w all pages printed
#  17145: Person 112 was attended by Printer 0 w all pages printed
#  17176: Person 113 is waiting for Printer 0
#  17176: Person 113 is ready to start using Printer 0
#  17177: Printer 0 is printing 8 pages in 24 secs
#  17201: Person 113 was attended by Printer 0 w all pages printed
#  17331: Person 114 is waiting for Printer 1
#  17331: Person 114 is ready to start using Printer 1
#  17332: Printer 1 is printing 23 pages in 115 secs
#  17433: Person 115 is waiting for Printer 1
#  17447: Person 114 was attended by Printer 1 w all pages printed
#  17448: Person 115 is ready to start using Printer 1
#  17449: Printer 1 is printing 21 pages in 105 secs
#  17486: Person 116 is waiting for Printer 1
#  17554: Person 115 was attended by Printer 1 w all pages printed
#  17555: Person 116 is ready to start using Printer 1
#  17556: Printer 1 is printing 19 pages in 95 secs
#  17627: Person 117 is waiting for Printer 1
#  17651: Person 116 was attended by Printer 1 w all pages printed
#  17652: Person 117 is ready to start using Printer 1
#  17653: Printer 1 is printing 20 pages in 100 secs
#  17682: Person 118 is waiting for Printer 1
#  17753: Person 117 was attended by Printer 1 w all pages printed
#  17754: Person 118 is ready to start using Printer 1
#  17755: Printer 1 is printing 24 pages in 120 secs
#  17857: Person 119 is waiting for Printer 0
#  17857: Person 119 is ready to start using Printer 0
#  17858: Printer 0 is printing 19 pages in 57 secs
#  17875: Person 118 was attended by Printer 1 w all pages printed
#  17915: Person 119 was attended by Printer 0 w all pages printed
#  18021: Person 120 is waiting for Printer 0
#  18021: Person 120 is ready to start using Printer 0
#  18022: Printer 0 is printing 15 pages in 45 secs
#  18067: Person 120 was attended by Printer 0 w all pages printed
#  18177: Person 121 is waiting for Printer 1
#  18177: Person 121 is ready to start using Printer 1
#  18178: Printer 1 is printing 23 pages in 115 secs
#  18293: Person 121 was attended by Printer 1 w all pages printed
#  18326: Person 122 is waiting for Printer 0
#  18326: Person 122 is ready to start using Printer 0
#  18327: Printer 0 is printing 14 pages in 42 secs
#  18369: Person 122 was attended by Printer 0 w all pages printed
#  18434: Person 123 is waiting for Printer 0
#  18434: Person 123 is ready to start using Printer 0
#  18435: Printer 0 is printing 25 pages in 75 secs
#  18510: Person 123 was attended by Printer 0 w all pages printed
#  18732: Person 124 is waiting for Printer 0
#  18732: Person 124 is ready to start using Printer 0
#  18733: Printer 0 is printing 13 pages in 39 secs
#  18772: Person 124 was attended by Printer 0 w all pages printed
#  18890: Person 125 is waiting for Printer 0
#  18890: Person 125 is ready to start using Printer 0
#  18891: Printer 0 is printing 25 pages in 75 secs
#  18900: Person 126 is waiting for Printer 0
#  18966: Person 125 was attended by Printer 0 w all pages printed
#  18967: Person 126 is ready to start using Printer 0
#  18968: Printer 0 is printing 7 pages in 21 secs
#  18989: Person 126 was attended by Printer 0 w all pages printed
#  19170: Person 127 is waiting for Printer 1
#  19170: Person 127 is ready to start using Printer 1
#  19171: Printer 1 is printing 22 pages in 110 secs
#  19281: Person 127 was attended by Printer 1 w all pages printed
#  19297: Person 128 is waiting for Printer 0
#  19297: Person 128 is ready to start using Printer 0
#  19298: Printer 0 is printing 22 pages in 66 secs
#  19364: Person 128 was attended by Printer 0 w all pages printed
#  19422: Person 129 is waiting for Printer 1
#  19422: Person 129 is ready to start using Printer 1
#  19423: Printer 1 is printing 6 pages in 30 secs
#  19453: Person 129 was attended by Printer 1 w all pages printed
#  19464: Person 130 is waiting for Printer 0
#  19464: Person 130 is ready to start using Printer 0
#  19465: Printer 0 is printing 5 pages in 15 secs
#  19480: Person 130 was attended by Printer 0 w all pages printed
#  19727: Person 131 is waiting for Printer 1
#  19727: Person 131 is ready to start using Printer 1
#  19728: Printer 1 is printing 19 pages in 95 secs
#  19823: Person 131 was attended by Printer 1 w all pages printed
#  19924: Person 132 is waiting for Printer 1
#  19924: Person 132 is ready to start using Printer 1
#  19925: Printer 1 is printing 17 pages in 85 secs
#  20010: Person 132 was attended by Printer 1 w all pages printed
#  20170: Person 133 is waiting for Printer 1
#  20170: Person 133 is ready to start using Printer 1
#  20171: Printer 1 is printing 16 pages in 80 secs
#  20251: Person 133 was attended by Printer 1 w all pages printed
#  20453: Person 134 is waiting for Printer 1
#  20453: Person 134 is ready to start using Printer 1
#  20454: Printer 1 is printing 20 pages in 100 secs
#  20554: Person 134 was attended by Printer 1 w all pages printed
#  20586: Person 135 is waiting for Printer 1
#  20586: Person 135 is ready to start using Printer 1
#  20587: Printer 1 is printing 22 pages in 110 secs
#  20697: Person 135 was attended by Printer 1 w all pages printed
#  20765: Person 136 is waiting for Printer 0
#  20765: Person 136 is ready to start using Printer 0
#  20766: Printer 0 is printing 11 pages in 33 secs
#  20799: Person 136 was attended by Printer 0 w all pages printed
#  20883: Person 137 is waiting for Printer 1
#  20883: Person 137 is ready to start using Printer 1
#  20884: Printer 1 is printing 16 pages in 80 secs
#  20900: Person 138 is waiting for Printer 1
#  20943: Person 139 is waiting for Printer 1
#  20964: Person 137 was attended by Printer 1 w all pages printed
#  20965: Person 138 is ready to start using Printer 1
#  20966: Printer 1 is printing 22 pages in 110 secs
#  21076: Person 138 was attended by Printer 1 w all pages printed
#  21077: Person 139 is ready to start using Printer 1
#  21078: Printer 1 is printing 21 pages in 105 secs
#  21183: Person 139 was attended by Printer 1 w all pages printed
#  21242: Person 140 is waiting for Printer 0
#  21242: Person 140 is ready to start using Printer 0
#  21243: Printer 0 is printing 25 pages in 75 secs
#  21318: Person 140 was attended by Printer 0 w all pages printed
#  21320: Person 141 is waiting for Printer 0
#  21320: Person 141 is ready to start using Printer 0
#  21321: Printer 0 is printing 9 pages in 27 secs
#  21348: Person 141 was attended by Printer 0 w all pages printed
#  21467: Person 142 is waiting for Printer 1
#  21467: Person 142 is ready to start using Printer 1
#  21468: Printer 1 is printing 15 pages in 75 secs
#  21530: Person 143 is waiting for Printer 0
#  21530: Person 143 is ready to start using Printer 0
#  21531: Printer 0 is printing 16 pages in 48 secs
#  21543: Person 142 was attended by Printer 1 w all pages printed
#  21579: Person 143 was attended by Printer 0 w all pages printed
#  21781: Person 144 is waiting for Printer 0
#  21781: Person 144 is ready to start using Printer 0
#  21782: Printer 0 is printing 7 pages in 21 secs
#  21803: Person 144 was attended by Printer 0 w all pages printed
#  21834: Person 145 is waiting for Printer 1
#  21834: Person 145 is ready to start using Printer 1
#  21835: Printer 1 is printing 8 pages in 40 secs
#  21848: Person 146 is waiting for Printer 0
#  21848: Person 146 is ready to start using Printer 0
#  21849: Printer 0 is printing 22 pages in 66 secs
#  21867: Person 147 is waiting for Printer 1
#  21875: Person 145 was attended by Printer 1 w all pages printed
#  21876: Person 147 is ready to start using Printer 1
#  21877: Printer 1 is printing 22 pages in 110 secs
#  21915: Person 146 was attended by Printer 0 w all pages printed
#  21987: Person 147 was attended by Printer 1 w all pages printed
#  22021: Person 148 is waiting for Printer 0
#  22021: Person 148 is ready to start using Printer 0
#  22022: Printer 0 is printing 23 pages in 69 secs
#  22091: Person 148 was attended by Printer 0 w all pages printed
#  22305: Person 149 is waiting for Printer 0
#  22305: Person 149 is ready to start using Printer 0
#  22306: Printer 0 is printing 7 pages in 21 secs
#  22327: Person 149 was attended by Printer 0 w all pages printed
#  22407: Person 150 is waiting for Printer 0
#  22407: Person 150 is ready to start using Printer 0
#  22408: Printer 0 is printing 6 pages in 18 secs
#  22426: Person 150 was attended by Printer 0 w all pages printed
#  22471: Person 151 is waiting for Printer 1
#  22471: Person 151 is ready to start using Printer 1
#  22472: Printer 1 is printing 8 pages in 40 secs
#  22512: Person 151 was attended by Printer 1 w all pages printed
#  22743: Person 152 is waiting for Printer 1
#  22743: Person 152 is ready to start using Printer 1
#  22744: Printer 1 is printing 10 pages in 50 secs
#  22752: Person 153 is waiting for Printer 0
#  22752: Person 153 is ready to start using Printer 0
#  22753: Printer 0 is printing 19 pages in 57 secs
#  22794: Person 152 was attended by Printer 1 w all pages printed
#  22810: Person 153 was attended by Printer 0 w all pages printed
#  22900: Person 154 is waiting for Printer 1
#  22900: Person 154 is ready to start using Printer 1
#  22901: Printer 1 is printing 7 pages in 35 secs
#  22936: Person 154 was attended by Printer 1 w all pages printed
#  22978: Person 155 is waiting for Printer 0
#  22978: Person 155 is ready to start using Printer 0
#  22979: Printer 0 is printing 18 pages in 54 secs
#  22990: Person 156 is waiting for Printer 0
#  23033: Person 155 was attended by Printer 0 w all pages printed
#  23034: Person 156 is ready to start using Printer 0
#  23035: Printer 0 is printing 25 pages in 75 secs
#  23072: Person 157 is waiting for Printer 0
#  23110: Person 156 was attended by Printer 0 w all pages printed
#  23111: Person 157 is ready to start using Printer 0
#  23112: Printer 0 is printing 24 pages in 72 secs
#  23184: Person 157 was attended by Printer 0 w all pages printed
#  23226: Person 158 is waiting for Printer 1
#  23226: Person 158 is ready to start using Printer 1
#  23227: Printer 1 is printing 16 pages in 80 secs
#  23307: Person 158 was attended by Printer 1 w all pages printed
#  23466: Person 159 is waiting for Printer 0
#  23466: Person 159 is ready to start using Printer 0
#  23467: Printer 0 is printing 22 pages in 66 secs
#  23533: Person 159 was attended by Printer 0 w all pages printed
#  23589: Person 160 is waiting for Printer 1
#  23589: Person 160 is ready to start using Printer 1
#  23590: Printer 1 is printing 13 pages in 65 secs
#  23655: Person 160 was attended by Printer 1 w all pages printed
#  23776: Person 161 is waiting for Printer 0
#  23776: Person 161 is ready to start using Printer 0
#  23777: Printer 0 is printing 17 pages in 51 secs
#  23828: Person 161 was attended by Printer 0 w all pages printed
#  23979: Person 162 is waiting for Printer 1
#  23979: Person 162 is ready to start using Printer 1
#  23980: Printer 1 is printing 16 pages in 80 secs
#  24060: Person 162 was attended by Printer 1 w all pages printed
#  24273: Person 163 is waiting for Printer 0
#  24273: Person 163 is ready to start using Printer 0
#  24274: Printer 0 is printing 22 pages in 66 secs
#  24340: Person 163 was attended by Printer 0 w all pages printed
#  24434: Person 164 is waiting for Printer 0
#  24434: Person 164 is ready to start using Printer 0
#  24435: Printer 0 is printing 10 pages in 30 secs
#  24465: Person 164 was attended by Printer 0 w all pages printed
#  24718: Person 165 is waiting for Printer 1
#  24718: Person 165 is ready to start using Printer 1
#  24719: Printer 1 is printing 23 pages in 115 secs
#  24834: Person 165 was attended by Printer 1 w all pages printed
#  24949: Person 166 is waiting for Printer 0
#  24949: Person 166 is ready to start using Printer 0
#  24950: Printer 0 is printing 15 pages in 45 secs
#  24995: Person 166 was attended by Printer 0 w all pages printed
#  25173: Person 167 is waiting for Printer 0
#  25173: Person 167 is ready to start using Printer 0
#  25174: Printer 0 is printing 11 pages in 33 secs
#  25198: Person 168 is waiting for Printer 1
#  25198: Person 168 is ready to start using Printer 1
#  25199: Printer 1 is printing 7 pages in 35 secs
#  25207: Person 167 was attended by Printer 0 w all pages printed
#  25234: Person 168 was attended by Printer 1 w all pages printed
#  25339: Person 169 is waiting for Printer 1
#  25339: Person 169 is ready to start using Printer 1
#  25340: Printer 1 is printing 16 pages in 80 secs
#  25420: Person 169 was attended by Printer 1 w all pages printed
#  25564: Person 170 is waiting for Printer 1
#  25564: Person 170 is ready to start using Printer 1
#  25565: Printer 1 is printing 24 pages in 120 secs
#  25587: Person 171 is waiting for Printer 1
#  25685: Person 170 was attended by Printer 1 w all pages printed
#  25686: Person 171 is ready to start using Printer 1
#  25687: Printer 1 is printing 20 pages in 100 secs
#  25728: Person 172 is waiting for Printer 0
#  25728: Person 172 is ready to start using Printer 0
#  25729: Printer 0 is printing 14 pages in 42 secs
#  25771: Person 172 was attended by Printer 0 w all pages printed
#  25787: Person 171 was attended by Printer 1 w all pages printed
#  25818: Person 173 is waiting for Printer 0
#  25818: Person 173 is ready to start using Printer 0
#  25819: Printer 0 is printing 14 pages in 42 secs
#  25861: Person 173 was attended by Printer 0 w all pages printed
#  25903: Person 174 is waiting for Printer 0
#  25903: Person 174 is ready to start using Printer 0
#  25904: Printer 0 is printing 23 pages in 69 secs
#  25912: Person 175 is waiting for Printer 1
#  25912: Person 175 is ready to start using Printer 1
#  25913: Printer 1 is printing 17 pages in 85 secs
#  25973: Person 174 was attended by Printer 0 w all pages printed
#  25998: Person 175 was attended by Printer 1 w all pages printed
#  26084: Person 176 is waiting for Printer 1
#  26084: Person 176 is ready to start using Printer 1
#  26085: Printer 1 is printing 5 pages in 25 secs
#  26110: Person 176 was attended by Printer 1 w all pages printed
#  26364: Person 177 is waiting for Printer 0
#  26364: Person 177 is ready to start using Printer 0
#  26365: Printer 0 is printing 16 pages in 48 secs
#  26371: Person 178 is waiting for Printer 0
#  26386: Person 179 is waiting for Printer 0
#  26413: Person 177 was attended by Printer 0 w all pages printed
#  26414: Person 178 is ready to start using Printer 0
#  26415: Printer 0 is printing 16 pages in 48 secs
#  26463: Person 178 was attended by Printer 0 w all pages printed
#  26464: Person 179 is ready to start using Printer 0
#  26465: Printer 0 is printing 19 pages in 57 secs
#  26522: Person 179 was attended by Printer 0 w all pages printed
#  26560: Person 180 is waiting for Printer 1
#  26560: Person 180 is ready to start using Printer 1
#  26561: Printer 1 is printing 24 pages in 120 secs
#  26672: Person 181 is waiting for Printer 0
#  26672: Person 181 is ready to start using Printer 0
#  26673: Printer 0 is printing 16 pages in 48 secs
#  26681: Person 180 was attended by Printer 1 w all pages printed
#  26721: Person 181 was attended by Printer 0 w all pages printed
#  26962: Person 182 is waiting for Printer 1
#  26962: Person 182 is ready to start using Printer 1
#  26963: Printer 1 is printing 19 pages in 95 secs
#  27000: Person 183 is waiting for Printer 0
#  27000: Person 183 is ready to start using Printer 0
#  27001: Printer 0 is printing 12 pages in 36 secs
#  27037: Person 183 was attended by Printer 0 w all pages printed
#  27058: Person 182 was attended by Printer 1 w all pages printed
#  27065: Person 184 is waiting for Printer 0
#  27065: Person 184 is ready to start using Printer 0
#  27066: Printer 0 is printing 18 pages in 54 secs
#  27120: Person 184 was attended by Printer 0 w all pages printed
#  27223: Person 185 is waiting for Printer 1
#  27223: Person 185 is ready to start using Printer 1
#  27224: Printer 1 is printing 18 pages in 90 secs
#  27314: Person 185 was attended by Printer 1 w all pages printed
#  27516: Person 186 is waiting for Printer 0
#  27516: Person 186 is ready to start using Printer 0
#  27517: Printer 0 is printing 16 pages in 48 secs
#  27562: Person 187 is waiting for Printer 1
#  27562: Person 187 is ready to start using Printer 1
#  27563: Printer 1 is printing 13 pages in 65 secs
#  27565: Person 186 was attended by Printer 0 w all pages printed
#  27628: Person 187 was attended by Printer 1 w all pages printed
#  27636: Person 188 is waiting for Printer 0
#  27636: Person 188 is ready to start using Printer 0
#  27637: Printer 0 is printing 13 pages in 39 secs
#  27676: Person 188 was attended by Printer 0 w all pages printed
#  27889: Person 189 is waiting for Printer 1
#  27889: Person 189 is ready to start using Printer 1
#  27890: Printer 1 is printing 6 pages in 30 secs
#  27920: Person 189 was attended by Printer 1 w all pages printed
#  27967: Person 190 is waiting for Printer 0
#  27967: Person 190 is ready to start using Printer 0
#  27968: Printer 0 is printing 16 pages in 48 secs
#  28016: Person 190 was attended by Printer 0 w all pages printed
#  28116: Person 191 is waiting for Printer 1
#  28116: Person 191 is ready to start using Printer 1
#  28117: Printer 1 is printing 22 pages in 110 secs
#  28208: Person 192 is waiting for Printer 1
#  28227: Person 191 was attended by Printer 1 w all pages printed
#  28228: Person 192 is ready to start using Printer 1
#  28229: Printer 1 is printing 22 pages in 110 secs
#  28339: Person 192 was attended by Printer 1 w all pages printed
#  28429: Person 193 is waiting for Printer 1
#  28429: Person 193 is ready to start using Printer 1
#  28430: Printer 1 is printing 5 pages in 25 secs
#  28455: Person 193 was attended by Printer 1 w all pages printed
#  28671: Person 194 is waiting for Printer 1
#  28671: Person 194 is ready to start using Printer 1
#  28672: Printer 1 is printing 25 pages in 125 secs
#  28797: Person 194 was attended by Printer 1 w all pages printed
#  28863: Person 195 is waiting for Printer 1
#  28863: Person 195 is ready to start using Printer 1
#  28864: Printer 1 is printing 24 pages in 120 secs
#  28984: Person 195 was attended by Printer 1 w all pages printed
#  29013: Person 196 is waiting for Printer 0
#  29013: Person 196 is ready to start using Printer 0
#  29014: Printer 0 is printing 5 pages in 15 secs
#  29029: Person 196 was attended by Printer 0 w all pages printed
#  29165: Person 197 is waiting for Printer 1
#  29165: Person 197 is ready to start using Printer 1
#  29166: Printer 1 is printing 8 pages in 40 secs
#  29206: Person 197 was attended by Printer 1 w all pages printed
#  29262: Person 198 is waiting for Printer 0
#  29262: Person 198 is ready to start using Printer 0
#  29263: Printer 0 is printing 11 pages in 33 secs
#  29296: Person 198 was attended by Printer 0 w all pages printed
#  29512: Person 199 is waiting for Printer 1
#  29512: Person 199 is ready to start using Printer 1
#  29513: Printer 1 is printing 8 pages in 40 secs
#  29553: Person 199 was attended by Printer 1 w all pages printed

# %% [markdown]
# ## recolectamos el dataframe de Impresoras y empezamos a unir el dataframe de Eventos

# %%
df_events = pd.DataFrame()

# %%
df_printers = pd.DataFrame()

for p in setup.printers:
    df_printers = pd.concat( [ df_printers , p.dfP ] )
    df_events = pd.concat( [ df_events , p.dfE ] )

# %%
df_printers
# Out:
#         name  speed  tank
# 0  Printer 0      3  1823
# 0  Printer 1      5  1698

# %% [markdown]
# ## recolectamos el dataframe de Personas y terminamos de unir el dataframe de Eventos

# %%
df_people = pd.DataFrame()

for p in setup.people:
    df_people = pd.concat( [ df_people , p.dfP ] )
    df_events = pd.concat( [ df_events , p.dfE ] )

# %%
df_people
# Out:
#           name    printer  num_pages
# 0     Person 0  Printer 1         18
# 0     Person 1  Printer 0         18
# 0     Person 2  Printer 0         10
# 0     Person 3  Printer 1         17
# 0     Person 4  Printer 1         12
# ..         ...        ...        ...
# 0   Person 195  Printer 1         24
# 0   Person 196  Printer 0          5
# 0   Person 197  Printer 1          8
# 0   Person 198  Printer 0         11
# 0   Person 199  Printer 1          8
#
# [200 rows x 3 columns]

# %%
df_events
# Out:
#      time    printer      person            event
# 0      88  Printer 0    Person 1         printing
# 0     375  Printer 0    Person 2         printing
# 0    1097  Printer 0    Person 6         printing
# 0    1547  Printer 0    Person 8         printing
# 0    1966  Printer 0   Person 11         printing
# ..    ...        ...         ...              ...
# 0   29206  Printer 1  Person 197         finished
# 0   29262  Printer 0  Person 198  waiting in line
# 0   29296  Printer 0  Person 198         finished
# 0   29512  Printer 1  Person 199  waiting in line
# 0   29553  Printer 1  Person 199         finished
#
# [600 rows x 4 columns]

# %% [markdown]
# ## Run Analysis!

# %% [markdown]
# Cuantas paginas imprimieron cada impresora

# %%
summPrinters =  df_people.groupby(
    ["printer"]
    , as_index=False
).agg({
    "num_pages": [ "sum" ]
    , "name": ["count"]
})

# %%
summPrinters
# Out:
#      printer num_pages  name
#                    sum count
# 0  Printer 0      1536    99
# 1  Printer 1      1650   101

# %%
summPrinters.columns = summPrinters.columns.droplevel(1)

# %%
df2 = df_printers.merge(
    summPrinters
    , left_on="name"
    , right_on="printer"
    , how="inner"
)

# %%
df2["FreePages"] = df2["tank"] - df2["num_pages"]

# %% [markdown]
# - num_pages: Total de paginas que la impresora imprimio
# - free pages: tank (capacidad maxima de impresión - num_pages) cuanto quedo libre para imprimir

# %%
df2
# Out:
#       name_x  speed  tank    printer  num_pages  name_y  FreePages
# 0  Printer 0      3  1823  Printer 0       1536      99        287
# 1  Printer 1      5  1698  Printer 1       1650     101         48

# %% [markdown]
# Como podemos observar Printer 0 tenia una capacidad maxima de 1823 paginas, atendio 1536 y aún le quedo libre 287 paginas

# %%
sample = df_events.loc[
    df_events["person"] == "Person 100"
    , :
].sort_values(  "time"   )

# %% [markdown]
# Aplicamos una función de ventada LEAD, la ventana la definimos por ```person``` para saber en que segundo sucedera el siguiente evento
#
# En clases tomamos como ejemplo una sola persona ``` Person 100``` para leer bien el calculo y aplicarlo despues a nuestro dataset completo

# %%
sample['lead'] = sample.groupby('person')['time'].shift(-1)

# %%
sample["time_on_event"] = sample["lead"] - sample["time"]

# %%
sample
# Out:
#     time    printer      person            event     lead  time_on_event
# 0  15161  Printer 0  Person 100  waiting in line  15162.0            1.0
# 0  15162  Printer 0  Person 100         printing  15213.0           51.0
# 0  15213  Printer 0  Person 100         finished      NaN            NaN

# %% [markdown]
# La persona 100 llego a la cola al segundo 15161 y fue atendida inmediatamente al siguiente segundo ya que no habia nadie en cola. Uso la impresora por 51 segundos
#
#
# Ahora corramos el calculo de LEAD para saber cuanto tiempo estuvo cada persona en cada evento

# %%
sample2 = df_events.sort_values(  ["person","time"]   )

# %%
sample2['lead'] = sample2.groupby('person')['time'].shift(-1)

# %%
sample2["time_on_event"] = sample2["lead"] - sample2["time"]

# %%
sample2
# Out:
#      time    printer     person            event     lead  time_on_event
# 0       0  Printer 1   Person 0  waiting in line      1.0            1.0
# 0       1  Printer 1   Person 0         printing     91.0           90.0
# 0      91  Printer 1   Person 0         finished      NaN            NaN
# 0      87  Printer 0   Person 1  waiting in line     88.0            1.0
# 0      88  Printer 0   Person 1         printing    142.0           54.0
# ..    ...        ...        ...              ...      ...            ...
# 0   14934  Printer 1  Person 98         printing  15054.0          120.0
# 0   15054  Printer 1  Person 98         finished      NaN            NaN
# 0   15043  Printer 1  Person 99  waiting in line  15056.0           13.0
# 0   15056  Printer 1  Person 99         printing  15081.0           25.0
# 0   15081  Printer 1  Person 99         finished      NaN            NaN
#
# [600 rows x 6 columns]

# %% [markdown]
# Ahora si quisieramos saber cuantas personas  esperaron mas de 1 segundo para ser atendidos

# %%
person_waiting = sample2.loc[ 
    ( sample2['time_on_event'] > 1 )
    &
    ( sample2['event'] == "waiting in line" )
, : ]

person_waiting
# Out:
#     time    printer      person            event     lead  time_on_event
# 0  17433  Printer 1  Person 115  waiting in line  17449.0           16.0
# 0  17486  Printer 1  Person 116  waiting in line  17556.0           70.0
# 0  17627  Printer 1  Person 117  waiting in line  17653.0           26.0
# 0  17682  Printer 1  Person 118  waiting in line  17755.0           73.0
# 0  18900  Printer 0  Person 126  waiting in line  18968.0           68.0
# 0  20900  Printer 1  Person 138  waiting in line  20966.0           66.0
# 0  20943  Printer 1  Person 139  waiting in line  21078.0          135.0
# 0  21867  Printer 1  Person 147  waiting in line  21877.0           10.0
# 0  22990  Printer 0  Person 156  waiting in line  23035.0           45.0
# 0  23072  Printer 0  Person 157  waiting in line  23112.0           40.0
# 0  25587  Printer 1  Person 171  waiting in line  25687.0          100.0
# 0  26371  Printer 0  Person 178  waiting in line  26415.0           44.0
# 0  26386  Printer 0  Person 179  waiting in line  26465.0           79.0
# 0  28208  Printer 1  Person 192  waiting in line  28229.0           21.0
# 0   3675  Printer 1   Person 22  waiting in line   3733.0           58.0
# 0   4613  Printer 1   Person 29  waiting in line   4620.0            7.0
# 0   7534  Printer 0   Person 47  waiting in line   7537.0            3.0
# 0   9363  Printer 1   Person 58  waiting in line   9449.0           86.0
# 0   9892  Printer 1   Person 62  waiting in line   9949.0           57.0
# 0   9962  Printer 1   Person 63  waiting in line  10046.0           84.0
# 0  12112  Printer 0   Person 77  waiting in line  12125.0           13.0
# 0  12489  Printer 0   Person 80  waiting in line  12510.0           21.0
# 0  13248  Printer 0   Person 85  waiting in line  13289.0           41.0
# 0  14503  Printer 1   Person 95  waiting in line  14563.0           60.0
# 0  15043  Printer 1   Person 99  waiting in line  15056.0           13.0

# %%
person_waiting.shape
# Out:
# (25, 6)

# %% [markdown]
# En total fueron 25 personas. ahora analizemos por impresora y cual fue el tiempo promedio de espera

# %%
person_waiting.groupby(
    "printer"
    , as_index=False
).agg({
    "time_on_event": [ "mean" ]
    , "person": [ "count" ]
})
# Out:
#      printer time_on_event person
#                       mean  count
# 0  Printer 0     39.333333      9
# 1  Printer 1     55.125000     16

# %% [markdown]
# Para ```impresora 0``` las 9 personas solo esperaron 39 segundos en promedio, y para la ```impresora 1``` en promedio esperarón casi el minuto
#
# En que hora de la simulación las impresoras dejaron de seguir atendiendo personas ?

# %%
timemax = df_events.groupby(
    "printer"
    , as_index=False
).agg({
    "time": [ "max" ] 
})

timemax.columns = ["printer","time"]

timemax["time"] = timemax["time"] / 60 / 60

# %%
timemax
# Out:
#      printer      time
# 0  Printer 0  8.137778
# 1  Printer 1  8.209167

# %% [markdown]
#  tiempo maximo de simulación fue de 30000 segundos, 8.33 horas. por lo que las impresoras atendieron a las 200 personas en un tiempo casi justo
#
#  De las 8.33 horas cuantas horas estuvieron activas y cuanto tiempo estuvieron paradas ?

# %%
printing = sample2.loc[ 
    df_events["event"] == "printing" 
    , :
].groupby(
    ["printer"]
    , as_index = False 
).agg({
    "time_on_event": ["sum"]
})

printing.columns = [ "printer" , "time_used" ]
printing["time_used"] = printing["time_used"] / 60 / 60 
printing["time_slept"] = 8.33 - printing["time_used"]

# %%
printing
# Out:
#      printer  time_used  time_slept
# 0  Printer 0   0.496667    7.833333
# 1  Printer 1   0.863889    7.466111

# %% [markdown]
# Como se puede observar las impresoras no fueron usadas tanto, pero por la manera en como se simulo la llegada de las personas si atendieron personas hasta el ultimo momento
#
# En promedio Cuanto tiempo estuvieron paradas las impresoras esperando a q llegara la siguiente persona ?

# %%
sample3 = df_events.sort_values( ["printer","time"] )

# %%
sample3["lead"] = sample3.groupby("printer")['time'].shift(-1)

# %%
sample3["time_on_event"] = sample3["lead"] - sample3["time"]

# %%
print_waiting = sample3.loc[ 
    sample3["event"] == "finished" 
, : ].groupby(
    ["printer"]
    , as_index=False
).agg({
    "time_on_event": ["mean","median"]
})

print_waiting.columns = ["printer","mean","median"]
print_waiting["mean"] = print_waiting["mean"] / 60
print_waiting["median"] = print_waiting["median"] / 60

# %%
print_waiting
# Out:
#      printer      mean    median
# 0  Printer 0  4.168537  3.466667
# 1  Printer 1  3.536333  2.658333

# %% [markdown]
# En promedio las impresoras estaban entre 2.6  - 4.1 minutos esperando a que llegara la siguiente persona
